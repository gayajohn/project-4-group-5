# %%
# importing pandas 
import pandas as pd

# %%
# merging two csv files 
df = pd.concat( 
    map(pd.read_csv, ['data_AP_1.csv', 'data_AP_2.csv', 'data_AP_3.csv', 'data_AP_4.csv','data_AP_5.csv', 
                      'data_AP_6.csv', 'data_AP_7.csv','data_AP_8.csv', 'data_AP_9.csv', 'data_AP_10.csv', 'data_AP_11.csv']), ignore_index=True) 

df = df.dropna()

# %%
df
# Out:
#                    industry       wr1       wr2       wr3       wr4  \
# 0                Technology  0.018456 -0.022085  0.074509  0.008752
# 1                Technology  0.077778 -0.024919 -0.043523 -0.030638
# 2    Consumer Discretionary -0.009910  0.001704  0.018177  0.038614
# 3                    Energy  0.033547  0.006861  0.011342  0.002944
# 4    Consumer Discretionary -0.034738  0.004087 -0.001657  0.046206
# ..                      ...       ...       ...       ...       ...
# 413                 Finance -0.005778  0.004001  0.016268  0.015779
# 416      Telecommunications -0.020692 -0.031341 -0.015429  0.013455
# 417              Technology -0.072525  0.026684  0.015746 -0.013580
# 418             Health Care -0.016372  0.017014  0.004806  0.007593
# 419             Industrials  0.035710 -0.022582  0.005130 -0.014781
#
#           vol1       vol2       vol3       vol4  pe_ratio  ...  profit_margin  \
# ...

# %%
df.to_csv('AP_Data_Final.csv')
