# %%
import pandas as pd

# %%
file_path = 'nasdaq_screener_1700335987448.csv'

# Read the CSV file into a Pandas DataFrame
stock_list_df = pd.read_csv(file_path)

# Display the DataFrame
stock_list_df.head()
# Out:
#   Symbol                                    Name Last Sale  Net Change  \
# 0      A  Agilent Technologies Inc. Common Stock   $113.15       -1.04
# 1   AAPL                 Apple Inc. Common Stock   $189.69       -0.02
# 2   ABBV                AbbVie Inc. Common Stock   $138.30        0.02
# 3   ABNB        Airbnb Inc. Class A Common Stock   $127.15        0.87
# 4    ABT        Abbott Laboratories Common Stock    $99.55       -0.71
#
#   % Change    Market Cap        Country  IPO Year    Volume  \
# 0   -0.91%  3.310625e+10  United States    1999.0   2700770
# 1   -0.01%  2.950200e+12  United States    1980.0  50922657
# 2    0.01%  2.441740e+11  United States    2012.0   4332297
# 3    0.69%  8.244890e+10  United States    2020.0   3795704
# 4   -0.71%  1.728250e+11  United States       NaN   6069070
#
#                    Sector                                    Industry
# 0             Industrials                         Electrical Products
# ...

# %%
file_path2 = 'Data_df/data_DP2.csv'
file_path3 = 'Data_df/data_DP3.csv'
file_path4 = 'Data_df/data_DP4.csv'
file_path5 = 'Data_df/data_DP5.csv'
file_path6 = 'Data_df/data_DP6.csv'
file_path7 = 'Data_df/data_DP7.csv'
file_path8 = 'Data_df/data_DP8.csv'
file_path9 = 'Data_df/data_DP9.csv'
file_path10 = 'Data_df/data_DP10.csv'
file_path11 = 'Data_df/data_DP11.csv'
file_path12 = 'Data_df/data_DP12.csv'
file_path13 = 'Data_df/data_DP13.csv'
file_path14 = 'Data_df/data_DP14.csv'

# %%
data_DP2 = pd.read_csv(file_path2)
data_DP3 = pd.read_csv(file_path3)
data_DP4 = pd.read_csv(file_path4)
data_DP5 = pd.read_csv(file_path5)
data_DP6 = pd.read_csv(file_path6)
data_DP7 = pd.read_csv(file_path7)
data_DP8 = pd.read_csv(file_path8)
data_DP9 = pd.read_csv(file_path9)
data_DP10 = pd.read_csv(file_path10)
data_DP11 = pd.read_csv(file_path11)
data_DP12 = pd.read_csv(file_path12)
data_DP13 = pd.read_csv(file_path13)
data_DP14 = pd.read_csv(file_path14)

# %%
concatenated_df = pd.concat([data_DP2, data_DP3,data_DP4, data_DP5, data_DP6, data_DP7, data_DP8, data_DP9, data_DP10, data_DP11, data_DP12, data_DP13, data_DP14], ignore_index=True)

# %%
concatenated_df
# Out:
#                    industry       wr1       wr2       wr3       wr4      vol1  \
# 0    Consumer Discretionary -0.019375  0.042774 -0.009555 -0.007692   6230100
# 1                 Utilities  0.025644  0.011924 -0.006826  0.031470    175800
# 2               Real Estate  0.057182 -0.004482 -0.040843  0.036994   1298900
# 3               Industrials -0.044857  0.062964  0.055392 -0.058078   1071300
# 4          Consumer Staples  0.022806 -0.021995  0.021842 -0.028000   6563300
# ..                      ...       ...       ...       ...       ...       ...
# 544             Health Care -0.006392  0.002918 -0.015773 -0.027340   1216800
# 545  Consumer Discretionary  0.035572 -0.015410 -0.015177 -0.004942  23388500
# 546                 Finance  0.006934  0.029712 -0.002174  0.087891    616500
# 547             Real Estate  0.042916  0.015226 -0.017039  0.026714   1736300
# 548              Technology -0.091923 -0.005320 -0.060329  0.035899   4395300
#
# ...

# %%
final_df = concatenated_df.dropna()

# %%
final_df
# Out:
#                    industry       wr1       wr2       wr3       wr4      vol1  \
# 0    Consumer Discretionary -0.019375  0.042774 -0.009555 -0.007692   6230100
# 1                 Utilities  0.025644  0.011924 -0.006826  0.031470    175800
# 2               Real Estate  0.057182 -0.004482 -0.040843  0.036994   1298900
# 3               Industrials -0.044857  0.062964  0.055392 -0.058078   1071300
# 4          Consumer Staples  0.022806 -0.021995  0.021842 -0.028000   6563300
# ..                      ...       ...       ...       ...       ...       ...
# 542              Technology  0.003835  0.116087  0.006430  0.019776   7664800
# 544             Health Care -0.006392  0.002918 -0.015773 -0.027340   1216800
# 545  Consumer Discretionary  0.035572 -0.015410 -0.015177 -0.004942  23388500
# 546                 Finance  0.006934  0.029712 -0.002174  0.087891    616500
# 548              Technology -0.091923 -0.005320 -0.060329  0.035899   4395300
#
# ...

# %%
final_df.to_csv('data_df/final_data_DP.csv', index=False)

# %%
path_DP = 'Data_df/final_data_DP.csv'
path_AP = 'Data_df/final_data_AP.csv'
path_GJ = 'Data_df/final_data_GJ.csv'
path_JB = 'Data_df/final_data_JB.csv'

data_DPF = pd.read_csv(path_DP)
data_APF = pd.read_csv(path_AP)
data_GJF = pd.read_csv(path_GJ)
data_JBF = pd.read_csv(path_JB)

# %%
final_compiled_df = pd.concat([data_DPF, data_APF, data_GJF, data_JBF], ignore_index=True)

# %%
final_compiled_df = final_compiled_df.drop(['Unnamed: 0'], axis=1)

# %%
final_compiled_df = final_compiled_df.dropna()

# %%
final_compiled_df.to_csv('ML_dataset.csv', index=False)
