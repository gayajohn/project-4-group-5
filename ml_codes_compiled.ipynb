# %% [markdown]
# ## Machine Learning
#
# In the following steps we will perform the following:
#
# - Prepare the dataset
# - Split in train and test
# - Transform/Encode the features kand labels
# - Test a wide range of ML models (Tree-based, Probabilistic and so on).
# - Compare the accuracry of all models.
# - Choose our winning model and tune hyperparameters to target a higher accuracy.
# - Make a more profound evaluation of the result with a confusion matrix and different measures.
# - Identify the most important features to predict the rating.

# %%
# Standard Library Imports
from pathlib import Path
import warnings
from random import sample

# Third-party Library Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import seaborn as sns
from scipy.stats import zscore

from xgboost import XGBClassifier
from sklearn import svm, metrics, preprocessing, model_selection
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, BaggingClassifier
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.decomposition import PCA
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.utils import resample
from scipy import stats
# Import the PCA module
from sklearn.decomposition import PCA

# TensorFlow and Keras Imports
import tensorflow as tf
import keras_tuner as kt

# Matplotlib and NumPy Imports
import matplotlib.ticker as mtick
import numpy as np
from numpy import loadtxt, sort
from matplotlib.ticker import PercentFormatter

# Data Processing Imports
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# XGBoost Imports
from xgboost import XGBClassifier

# Seaborn Import
import seaborn as sns
sns.set(style="whitegrid")

# Ignore all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Reading in data from SQL database

# %%
# starting a sql engine 

# Replace these values with your database credentials
db_host = "127.0.0.1"
db_port = "5432"
db_name = "machinelearningDB"
db_user = "postgres"
db_password = "postgres"

# Create a PostgreSQL database connection using SQLAlchemy
engine = create_engine(f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}")

# Create a Session class to interact with the database
Session = sessionmaker(bind=engine)

# Establish a session to execute SQL queries
try:
    session = Session()

    # Example: Execute a simple SQL query
    result = session.execute("SELECT version();")
    version = result.scalar()
    print("Connected to the database. PostgreSQL version:", version)


except Exception as e:
    print("Error while connecting to PostgreSQL:", e)
# Out:
# Connected to the database. PostgreSQL version: PostgreSQL 12.15, compiled by Visual C++ build 1914, 64-bit

# %%
# reading in sql table and saving as dataframe
df = pd.read_sql_query(f"SELECT * FROM stock_data", con=engine)
df.head()
# Out:
#                  industry       wr1       wr2       wr3       wr4       vol1  \
# 0  Consumer Discretionary -0.019375  0.042774 -0.009555 -0.007692  6230100.0
# 1               Utilities  0.025644  0.011924 -0.006826  0.031470   175800.0
# 2             Real Estate  0.057182 -0.004482 -0.040843  0.036994  1298900.0
# 3             Industrials -0.044857  0.062964  0.055392 -0.058078  1071300.0
# 4        Consumer Staples  0.022806 -0.021995  0.021842 -0.028000  6563300.0
#
#         vol2       vol3        vol4  pe_ratio  ...  profit_margin  \
# 0  6996900.0  6377700.0   7026700.0     30.01  ...          14.40
# 1   195300.0   233900.0    221400.0     17.58  ...          11.15
# 2  3493600.0   571100.0    832500.0     62.13  ...          12.97
# 3   880100.0  1080400.0    994800.0      6.68  ...          27.43
# 4  6745100.0  9474700.0  10172500.0     10.28  ...           4.55
#
#    free_cash_margin  volatility      cpi  interest_rate  unemployment_rate  \
# 0             13.74    0.025251  241.428           0.40                5.0
# 1              1.49    0.013118  238.132           0.36                5.0
# 2             29.98    0.019104  237.838           0.13                5.0
# 3            -18.14    0.023650  305.691           5.08                3.5
# 4             10.21    0.019597  259.101           0.10               10.2
#
#           sma        rsi         ema  label
# 0   56.240000   8.149406   56.300000      0
# 1   73.803333  87.796610   73.714583      0
# 2   23.196667  88.260870   23.240833      0
# 3  235.736667  11.037986  235.240833      0
# 4   63.633333  72.448980   63.837083      1
#
# [5 rows x 23 columns]

# %%
# getting df info to ensure no null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1914 entries, 0 to 1913
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   industry                  1914 non-null   object
#  1   wr1                       1914 non-null   float64
#  2   wr2                       1914 non-null   float64
#  3   wr3                       1914 non-null   float64
#  4   wr4                       1914 non-null   float64
#  5   vol1                      1914 non-null   float64
#  6   vol2                      1914 non-null   float64
#  7   vol3                      1914 non-null   float64
#  8   vol4                      1914 non-null   float64
#  9   pe_ratio                  1914 non-null   float64
#  10  debt_to_equity            1914 non-null   float64
#  11  quick_ratio               1914 non-null   float64
#  12  total_shareholder_return  1914 non-null   float64
#  13  profit_margin             1914 non-null   float64
#  14  free_cash_margin          1914 non-null   float64
#  15  volatility                1914 non-null   float64
#  16  cpi                       1914 non-null   float64
#  17  interest_rate             1914 non-null   float64
#  18  unemployment_rate         1914 non-null   float64
#  19  sma                       1914 non-null   float64
#  20  rsi                       1914 non-null   float64
#  21  ema                       1914 non-null   float64
#  22  label                     1914 non-null   int64
# dtypes: float64(21), int64(1), object(1)
# memory usage: 344.0+ KB

# %% [markdown]
# ## Preprocessing the data
#
# - Separate the label and features
# - Encode numerical columns, in this case, the industry column
# - Split the data into training and testing data
# - Scaling the data based on the training data

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
y = df["label"]

# Separate the X variable, the features
X = df.drop(columns="label")

# %%
# Review the y variable Series
y[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: label, dtype: int64

# %%
# Review the X variable DataFrame
X[:5]
# Out:
#                  industry       wr1       wr2       wr3       wr4       vol1  \
# 0  Consumer Discretionary -0.019375  0.042774 -0.009555 -0.007692  6230100.0
# 1               Utilities  0.025644  0.011924 -0.006826  0.031470   175800.0
# 2             Real Estate  0.057182 -0.004482 -0.040843  0.036994  1298900.0
# 3             Industrials -0.044857  0.062964  0.055392 -0.058078  1071300.0
# 4        Consumer Staples  0.022806 -0.021995  0.021842 -0.028000  6563300.0
#
#         vol2       vol3        vol4  pe_ratio  ...  total_shareholder_return  \
# 0  6996900.0  6377700.0   7026700.0     30.01  ...                      3.80
# 1   195300.0   233900.0    221400.0     17.58  ...                      2.64
# 2  3493600.0   571100.0    832500.0     62.13  ...                      4.97
# 3   880100.0  1080400.0    994800.0      6.68  ...                      0.66
# 4  6745100.0  9474700.0  10172500.0     10.28  ...                      2.18
#
#    profit_margin  free_cash_margin  volatility      cpi  interest_rate  \
# 0          14.40             13.74    0.025251  241.428           0.40
# 1          11.15              1.49    0.013118  238.132           0.36
# 2          12.97             29.98    0.019104  237.838           0.13
# 3          27.43            -18.14    0.023650  305.691           5.08
# 4           4.55             10.21    0.019597  259.101           0.10
#
#    unemployment_rate         sma        rsi         ema
# 0                5.0   56.240000   8.149406   56.300000
# 1                5.0   73.803333  87.796610   73.714583
# 2                5.0   23.196667  88.260870   23.240833
# 3                3.5  235.736667  11.037986  235.240833
# 4               10.2   63.633333  72.448980   63.837083
#
# [5 rows x 22 columns]

# %%
# One-hot encode the 'industry' column
X = pd.get_dummies(X, columns=['industry'])

X.head()
# Out:
#         wr1       wr2       wr3       wr4       vol1       vol2       vol3  \
# 0 -0.019375  0.042774 -0.009555 -0.007692  6230100.0  6996900.0  6377700.0
# 1  0.025644  0.011924 -0.006826  0.031470   175800.0   195300.0   233900.0
# 2  0.057182 -0.004482 -0.040843  0.036994  1298900.0  3493600.0   571100.0
# 3 -0.044857  0.062964  0.055392 -0.058078  1071300.0   880100.0  1080400.0
# 4  0.022806 -0.021995  0.021842 -0.028000  6563300.0  6745100.0  9474700.0
#
#          vol4  pe_ratio  debt_to_equity  ...  industry_Consumer Staples  \
# 0   7026700.0     30.01            0.63  ...                      False
# 1    221400.0     17.58            0.85  ...                      False
# 2    832500.0     62.13            0.60  ...                      False
# 3    994800.0      6.68            0.36  ...                      False
# 4  10172500.0     10.28            1.35  ...                       True
#
#    industry_Energy  industry_Finance  industry_Health Care  \
# 0            False             False                 False
# 1            False             False                 False
# 2            False             False                 False
# 3            False             False                 False
# 4            False             False                 False
#
#    industry_Industrials  industry_Miscellaneous  industry_Real Estate  \
# 0                 False                   False                 False
# 1                 False                   False                 False
# 2                 False                   False                  True
# 3                  True                   False                 False
# 4                 False                   False                 False
#
#    industry_Technology  industry_Telecommunications  industry_Utilities
# 0                False                        False               False
# 1                False                        False                True
# 2                False                        False               False
# 3                False                        False               False
# 4                False                        False               False
#
# [5 rows x 34 columns]

# %%
# reviewing new featureset
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1914 entries, 0 to 1913
# Data columns (total 34 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   wr1                              1914 non-null   float64
#  1   wr2                              1914 non-null   float64
#  2   wr3                              1914 non-null   float64
#  3   wr4                              1914 non-null   float64
#  4   vol1                             1914 non-null   float64
#  5   vol2                             1914 non-null   float64
#  6   vol3                             1914 non-null   float64
#  7   vol4                             1914 non-null   float64
#  8   pe_ratio                         1914 non-null   float64
#  9   debt_to_equity                   1914 non-null   float64
#  10  quick_ratio                      1914 non-null   float64
#  11  total_shareholder_return         1914 non-null   float64
#  12  profit_margin                    1914 non-null   float64
#  13  free_cash_margin                 1914 non-null   float64
#  14  volatility                       1914 non-null   float64
#  15  cpi                              1914 non-null   float64
#  16  interest_rate                    1914 non-null   float64
#  17  unemployment_rate                1914 non-null   float64
#  18  sma                              1914 non-null   float64
#  19  rsi                              1914 non-null   float64
#  20  ema                              1914 non-null   float64
#  21  industry_Basic Materials         1914 non-null   bool
#  22  industry_Communication Services  1914 non-null   bool
#  23  industry_Consumer Discretionary  1914 non-null   bool
#  24  industry_Consumer Staples        1914 non-null   bool
#  25  industry_Energy                  1914 non-null   bool
#  26  industry_Finance                 1914 non-null   bool
#  27  industry_Health Care             1914 non-null   bool
#  28  industry_Industrials             1914 non-null   bool
#  29  industry_Miscellaneous           1914 non-null   bool
#  30  industry_Real Estate             1914 non-null   bool
#  31  industry_Technology              1914 non-null   bool
#  32  industry_Telecommunications      1914 non-null   bool
#  33  industry_Utilities               1914 non-null   bool
# dtypes: bool(13), float64(21)
# memory usage: 338.4 KB

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## List of Machine Learning Models Used:
#
# #### 1. Random Forest (RF)
# #### 2. XG Boost (XGB)
# #### 3. Tensor Flow (TF)
# #### 4. Logistic Regression (LR)
# #### 5. Linear Discriminant Analysis (LDT)
# #### 6. Neural Network (MLP)
# #### 7. K-Nearest Neighbors Algorithm (KNN)
# #### 8. Decision Tree Algorithm (DT)
# #### 9. Bagging Decision Tree (BGT)
# #### 10. Gradient Boosting Classifier (GBT)
# #### 11. Support Vector Machine (SVM)
# #### 12. Naive Bayes Classifier (NB)

# %% [markdown]
# ### 1. Predicting the label using Random Forest

# %%
RF_model = RandomForestClassifier(random_state=1234)
RF_model.fit(X_train_scaled,y_train)

RF_training_predictions = RF_model.predict(X_train_scaled)
y_pred_RF = RF_model.predict(X_test_scaled)

Accuracy_RF = metrics.accuracy_score(y_test, y_pred_RF)

print("RF Accuracy:",Accuracy_RF)
# Out:
# RF Accuracy: 0.5031315240083507

# %%
# Generate the confusion matrix
cm_RF = confusion_matrix(y_test, y_pred_RF)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_RF, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Random Forest Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

# Create and save the training classification report
training_report_RF = classification_report(y_train, RF_training_predictions)
testing_report_RF = classification_report(y_test, y_pred_RF)

# Print the training classification report
print("Random Forest Classification Report: Training Data")
print("---------------------------------------------------")
print(training_report_RF)
print("")
print("Random Forest Classification Report: Testing Data")
print("---------------------------------------------------")
print(testing_report_RF)
# Out:
# Random Forest Classification Report: Training Data
# ---------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       682
#            1       1.00      1.00      1.00       753
#
#     accuracy                           1.00      1435
#    macro avg       1.00      1.00      1.00      1435
# weighted avg       1.00      1.00      1.00      1435
#
#
# Random Forest Classification Report: Testing Data
# ---------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.46      0.41      0.43       220
#            1       0.54      0.58      0.56       259
#
#     accuracy                           0.50       479
#    macro avg       0.50      0.50      0.50       479
# weighted avg       0.50      0.50      0.50       479

# %% [markdown]
# #### From the matrix above it appears we have an over-fitting problem
# ______________________________________________________________________________________________________________________________

# %% [markdown]
# ### 2. Predicting the label using XGBoost

# %%
# Create a binary XGBoost model
XGB_model = xgb.XGBClassifier(objective='binary:logistic')

# Train the model
XGB_model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred_XGB = XGB_model.predict(X_test_scaled)

# Calculate accuracy
accuracy_XGB = metrics.accuracy_score(y_test, y_pred_XGB)
print("XGB Accuracy (Binary Classification):", accuracy_XGB)
# Out:
# XGB Accuracy (Binary Classification): 0.5615866388308977

# %%
# Generate the confusion matrix
cm_XGB = confusion_matrix(y_test, y_pred_XGB)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_XGB, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('XGBoost Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

# Create and save the training classification report
XGB_training_predictions = XGB_model.predict(X_train_scaled)

training_report = classification_report(y_train, XGB_training_predictions)
testing_report = classification_report(y_test, y_pred_XGB)

# Print the training classification report
print("XGBoost Classification Report: Training Data")
print("---------------------------------------------")
print(training_report_RF)
print("")
print("XGBoost Classification Report: Testing Data")
print("--------------------------------------------")
print(testing_report_RF)
# Out:
# XGBoost Classification Report: Training Data
# ---------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       682
#            1       1.00      1.00      1.00       753
#
#     accuracy                           1.00      1435
#    macro avg       1.00      1.00      1.00      1435
# weighted avg       1.00      1.00      1.00      1435
#
#
# XGBoost Classification Report: Testing Data
# --------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.46      0.41      0.43       220
#            1       0.54      0.58      0.56       259
#
#     accuracy                           0.50       479
#    macro avg       0.50      0.50      0.50       479
# weighted avg       0.50      0.50      0.50       479

# %% [markdown]
# #### Once again, we appear to have an over-fitting problem
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ### 3. Predicting the label with Tensor Flow

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 80)                2800
#
#  dense_13 (Dense)            (None, 30)                2430
#
#  dense_14 (Dense)            (None, 20)                620
#
#  dense_15 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 5871 (22.93 KB)
# Trainable params: 5871 (22.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
           
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
           
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 45/45 [==============================] - 3s 5ms/step - loss: 0.6983 - accuracy: 0.5164
# Epoch 2/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6758 - accuracy: 0.5686
# Epoch 3/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6653 - accuracy: 0.6056
# Epoch 4/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6547 - accuracy: 0.6084
# Epoch 5/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.6471 - accuracy: 0.6195
# Epoch 6/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6350 - accuracy: 0.6418
# Epoch 7/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6258 - accuracy: 0.6564
# Epoch 8/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6126 - accuracy: 0.6655
# Epoch 9/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6037 - accuracy: 0.6669
# Epoch 10/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.5912 - accuracy: 0.6787
# Epoch 11/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5778 - accuracy: 0.7052
# Epoch 12/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5767 - accuracy: 0.6892
# Epoch 13/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5603 - accuracy: 0.7143
# Epoch 14/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5475 - accuracy: 0.7261
# Epoch 15/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5377 - accuracy: 0.7213
# Epoch 16/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5291 - accuracy: 0.7226
# Epoch 17/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5187 - accuracy: 0.7394
# Epoch 18/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.5057 - accuracy: 0.7456
# Epoch 19/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4923 - accuracy: 0.7568
# Epoch 20/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4851 - accuracy: 0.7659
# Epoch 21/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4709 - accuracy: 0.7791
# Epoch 22/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4663 - accuracy: 0.7735
# Epoch 23/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4549 - accuracy: 0.7847
# Epoch 24/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4380 - accuracy: 0.7965
# Epoch 25/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4289 - accuracy: 0.7993
# Epoch 26/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4229 - accuracy: 0.7993
# Epoch 27/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4089 - accuracy: 0.8118
# Epoch 28/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3984 - accuracy: 0.8230
# Epoch 29/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3998 - accuracy: 0.8118
# Epoch 30/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3816 - accuracy: 0.8237
# Epoch 31/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3681 - accuracy: 0.8355
# Epoch 32/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3737 - accuracy: 0.8300
# Epoch 33/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3645 - accuracy: 0.8425
# Epoch 34/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3475 - accuracy: 0.8523
# Epoch 35/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3404 - accuracy: 0.8557
# Epoch 36/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3276 - accuracy: 0.8530
# Epoch 37/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3346 - accuracy: 0.8578
# Epoch 38/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3158 - accuracy: 0.8711
# Epoch 39/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3144 - accuracy: 0.8641
# Epoch 40/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2986 - accuracy: 0.8808
# Epoch 41/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2916 - accuracy: 0.8829
# Epoch 42/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.2871 - accuracy: 0.8836
# Epoch 43/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2733 - accuracy: 0.8864
# Epoch 44/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2726 - accuracy: 0.8843
# Epoch 45/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2600 - accuracy: 0.9052
# Epoch 46/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2545 - accuracy: 0.8983
# Epoch 47/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2518 - accuracy: 0.9059
# Epoch 48/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2434 - accuracy: 0.9136
# Epoch 49/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2383 - accuracy: 0.9024
# Epoch 50/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2299 - accuracy: 0.9129
# Epoch 51/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2218 - accuracy: 0.9171
# Epoch 52/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2201 - accuracy: 0.9213
# Epoch 53/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2452 - accuracy: 0.9226
# Epoch 54/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2092 - accuracy: 0.9213
# Epoch 55/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1980 - accuracy: 0.9261
# Epoch 56/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1890 - accuracy: 0.9359
# Epoch 57/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1870 - accuracy: 0.9303
# Epoch 58/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1841 - accuracy: 0.9338
# Epoch 59/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1844 - accuracy: 0.9394
# Epoch 60/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.1830 - accuracy: 0.9380
# Epoch 61/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1697 - accuracy: 0.9429
# Epoch 62/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1605 - accuracy: 0.9512
# Epoch 63/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1570 - accuracy: 0.9463
# Epoch 64/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1509 - accuracy: 0.9519
# Epoch 65/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1453 - accuracy: 0.9554
# Epoch 66/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1512 - accuracy: 0.9470
# Epoch 67/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1388 - accuracy: 0.9631
# Epoch 68/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1373 - accuracy: 0.9575
# Epoch 69/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1394 - accuracy: 0.9512
# Epoch 70/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1240 - accuracy: 0.9666
# Epoch 71/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1213 - accuracy: 0.9638
# Epoch 72/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1343 - accuracy: 0.9575
# Epoch 73/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1715 - accuracy: 0.9449
# Epoch 74/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1663 - accuracy: 0.9505
# Epoch 75/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1395 - accuracy: 0.9554
# Epoch 76/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1478 - accuracy: 0.9519
# Epoch 77/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1280 - accuracy: 0.9624
# Epoch 78/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1124 - accuracy: 0.9693
# Epoch 79/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1026 - accuracy: 0.9700
# Epoch 80/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0972 - accuracy: 0.9756
# Epoch 81/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0903 - accuracy: 0.9770
# Epoch 82/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0996 - accuracy: 0.9707
# Epoch 83/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0937 - accuracy: 0.9770
# Epoch 84/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0899 - accuracy: 0.9749
# Epoch 85/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0820 - accuracy: 0.9840
# Epoch 86/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0803 - accuracy: 0.9826
# Epoch 87/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0763 - accuracy: 0.9847
# Epoch 88/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0733 - accuracy: 0.9840
# Epoch 89/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9826
# Epoch 90/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0720 - accuracy: 0.9833
# Epoch 91/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0712 - accuracy: 0.9819
# Epoch 92/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0652 - accuracy: 0.9854
# Epoch 93/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0615 - accuracy: 0.9882
# Epoch 94/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0605 - accuracy: 0.9875
# Epoch 95/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0574 - accuracy: 0.9909
# Epoch 96/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0675 - accuracy: 0.9854
# Epoch 97/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0666 - accuracy: 0.9868
# Epoch 98/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0611 - accuracy: 0.9902
# Epoch 99/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0527 - accuracy: 0.9909
# Epoch 100/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0504 - accuracy: 0.9916
# 15/15 - 0s - loss: 3.4280 - accuracy: 0.5198 - 445ms/epoch - 30ms/step
# Loss: 3.4279682636260986, Accuracy: 0.519832968711853

# %%
Accuracy_TF1 = model_accuracy

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  100
hidden_nodes_layer2 = 60
hidden_nodes_layer3 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="tanh")
)
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 100)               3500
#
#  dense_17 (Dense)            (None, 60)                6060
#
#  dense_18 (Dense)            (None, 30)                1830
#
#  dense_19 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 11421 (44.61 KB)
# Trainable params: 11421 (44.61 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
           
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
           
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 45/45 [==============================] - 3s 5ms/step - loss: 0.7107 - accuracy: 0.5185
# Epoch 2/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6917 - accuracy: 0.5261
# Epoch 3/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6856 - accuracy: 0.5429
# Epoch 4/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6776 - accuracy: 0.5540
# Epoch 5/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6734 - accuracy: 0.5686
# Epoch 6/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6695 - accuracy: 0.5742
# Epoch 7/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6651 - accuracy: 0.5805
# Epoch 8/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6598 - accuracy: 0.5895
# Epoch 9/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6556 - accuracy: 0.5972
# Epoch 10/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6488 - accuracy: 0.6146
# Epoch 11/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6460 - accuracy: 0.6105
# Epoch 12/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6408 - accuracy: 0.6265
# Epoch 13/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6322 - accuracy: 0.6397
# Epoch 14/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6270 - accuracy: 0.6411
# Epoch 15/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6209 - accuracy: 0.6481
# Epoch 16/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6167 - accuracy: 0.6516
# Epoch 17/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6105 - accuracy: 0.6690
# Epoch 18/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.5998 - accuracy: 0.6808
# Epoch 19/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5969 - accuracy: 0.6801
# Epoch 20/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5869 - accuracy: 0.6920
# Epoch 21/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5824 - accuracy: 0.6990
# Epoch 22/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5739 - accuracy: 0.6976
# Epoch 23/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5668 - accuracy: 0.7157
# Epoch 24/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5604 - accuracy: 0.7129
# Epoch 25/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5494 - accuracy: 0.7345
# Epoch 26/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5444 - accuracy: 0.7338
# Epoch 27/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5388 - accuracy: 0.7366
# Epoch 28/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5306 - accuracy: 0.7436
# Epoch 29/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5256 - accuracy: 0.7449
# Epoch 30/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5129 - accuracy: 0.7484
# Epoch 31/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5048 - accuracy: 0.7533
# Epoch 32/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4910 - accuracy: 0.7805
# Epoch 33/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4856 - accuracy: 0.7672
# Epoch 34/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4746 - accuracy: 0.7826
# Epoch 35/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4700 - accuracy: 0.7944
# Epoch 36/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4572 - accuracy: 0.7937
# Epoch 37/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4497 - accuracy: 0.7868
# Epoch 38/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4478 - accuracy: 0.7972
# Epoch 39/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4353 - accuracy: 0.8063
# Epoch 40/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4212 - accuracy: 0.8167
# Epoch 41/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4116 - accuracy: 0.8174
# Epoch 42/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4011 - accuracy: 0.8328
# Epoch 43/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3869 - accuracy: 0.8432
# Epoch 44/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3843 - accuracy: 0.8369
# Epoch 45/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3742 - accuracy: 0.8425
# Epoch 46/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3600 - accuracy: 0.8537
# Epoch 47/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3531 - accuracy: 0.8571
# Epoch 48/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3492 - accuracy: 0.8655
# Epoch 49/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3374 - accuracy: 0.8690
# Epoch 50/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3278 - accuracy: 0.8801
# Epoch 51/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3171 - accuracy: 0.8767
# Epoch 52/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3030 - accuracy: 0.8746
# Epoch 53/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2996 - accuracy: 0.8829
# Epoch 54/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2868 - accuracy: 0.8983
# Epoch 55/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2763 - accuracy: 0.8976
# Epoch 56/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2658 - accuracy: 0.9052
# Epoch 57/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2595 - accuracy: 0.9094
# Epoch 58/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2529 - accuracy: 0.9094
# Epoch 59/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2469 - accuracy: 0.9157
# Epoch 60/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2280 - accuracy: 0.9275
# Epoch 61/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2238 - accuracy: 0.9240
# Epoch 62/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2117 - accuracy: 0.9310
# Epoch 63/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2096 - accuracy: 0.9338
# Epoch 64/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1993 - accuracy: 0.9352
# Epoch 65/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1949 - accuracy: 0.9394
# Epoch 66/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1906 - accuracy: 0.9394
# Epoch 67/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1852 - accuracy: 0.9373
# Epoch 68/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1731 - accuracy: 0.9505
# Epoch 69/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1686 - accuracy: 0.9456
# Epoch 70/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1589 - accuracy: 0.9547
# Epoch 71/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1528 - accuracy: 0.9568
# Epoch 72/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1485 - accuracy: 0.9589
# Epoch 73/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1391 - accuracy: 0.9638
# Epoch 74/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1369 - accuracy: 0.9596
# Epoch 75/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1282 - accuracy: 0.9666
# Epoch 76/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1243 - accuracy: 0.9693
# Epoch 77/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1275 - accuracy: 0.9679
# Epoch 78/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1145 - accuracy: 0.9707
# Epoch 79/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1121 - accuracy: 0.9686
# Epoch 80/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1026 - accuracy: 0.9749
# Epoch 81/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1031 - accuracy: 0.9770
# Epoch 82/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1003 - accuracy: 0.9770
# Epoch 83/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0941 - accuracy: 0.9777
# Epoch 84/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0896 - accuracy: 0.9798
# Epoch 85/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0850 - accuracy: 0.9805
# Epoch 86/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0837 - accuracy: 0.9819
# Epoch 87/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0771 - accuracy: 0.9861
# Epoch 88/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0709 - accuracy: 0.9895
# Epoch 89/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0689 - accuracy: 0.9833
# Epoch 90/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0678 - accuracy: 0.9861
# Epoch 91/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0643 - accuracy: 0.9909
# Epoch 92/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0600 - accuracy: 0.9923
# Epoch 93/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0584 - accuracy: 0.9909
# Epoch 94/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0573 - accuracy: 0.9895
# Epoch 95/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0545 - accuracy: 0.9909
# Epoch 96/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0489 - accuracy: 0.9944
# Epoch 97/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0455 - accuracy: 0.9972
# Epoch 98/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0450 - accuracy: 0.9958
# Epoch 99/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0421 - accuracy: 0.9930
# Epoch 100/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0418 - accuracy: 0.9902
# 15/15 - 0s - loss: 1.9603 - accuracy: 0.5407 - 402ms/epoch - 27ms/step
# Loss: 1.9603184461593628, Accuracy: 0.5407097935676575

# %%
Accuracy_TF2 = model_accuracy

# %% [markdown]
# ### 4. Predicting the label with Logistic Regression

# %%
LR_model = LogisticRegression(random_state=1234 , solver='lbfgs')
LR_model = LR_model.fit(X_train_scaled, y_train)
LR_training_predictions = LR_model.predict(X_train_scaled)
y_pred_LR = LR_model.predict(X_test_scaled)
Accuracy_LR = metrics.accuracy_score(y_test, y_pred_LR)

print("LR Accuracy:",Accuracy_LR)
# Out:
# LR Accuracy: 0.5323590814196242

# %%
# Generate the confusion matrix
cm_LR = confusion_matrix(y_test, y_pred_LR)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_LR, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Logistic Regression Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

# Create and save the training classification report
training_report_LR = classification_report(y_train, RF_training_predictions)
testing_report_LR = classification_report(y_test, y_pred_LR)

# Print the training classification report
print("Logistic Regression Classification Report: Training Data")
print("----------------------------------------------------------")
print(training_report_LR)
print("")
print("Logistic Regression Classification Report: Testing Data")
print("---------------------------------------------------------")
print(testing_report_LR)
# Out:
# Logistic Regression Classification Report: Training Data
# ----------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       682
#            1       1.00      1.00      1.00       753
#
#     accuracy                           1.00      1435
#    macro avg       1.00      1.00      1.00      1435
# weighted avg       1.00      1.00      1.00      1435
#
#
# Logistic Regression Classification Report: Testing Data
# ---------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.49      0.36      0.42       220
#            1       0.56      0.68      0.61       259
#
#     accuracy                           0.53       479
#    macro avg       0.52      0.52      0.51       479
# weighted avg       0.52      0.53      0.52       479

# %% [markdown]
# ### 5. Predicting the label with Linear Discrimant Analysis

# %%
LDA_model = LinearDiscriminantAnalysis()
LDA_model.fit(X_train_scaled,y_train)
LDA_training_predictions = LDA_model.predict(X_train_scaled) 
y_pred_LDA = LDA_model.predict(X_test_scaled)
Accuracy_LDA = metrics.accuracy_score(y_test, y_pred_LDA)

print("LDA Accuracy:",Accuracy_LDA)
# Out:
# LDA Accuracy: 0.5302713987473904

# %%
# Generate the confusion matrix
cm_LDA = confusion_matrix(y_test, y_pred_LDA)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_LDA, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Linear Discriminant Analysis Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

 # Create and save the training classification report
training_report_LDA = classification_report(y_train, LDA_training_predictions)
testing_report_LDA = classification_report(y_test, y_pred_LDA)

# Print the training classification report
print("Linear Discriminant Analysis Classification Report: Training Data")
print("-------------------------------------------------------------------")
print(training_report_LDA)
print("")
print("Linear Discriminant Analysis Classification Report: Testing Data")
print("-------------------------------------------------------------------")
print(testing_report_LDA)
# Out:
# Linear Discriminant Analysis Classification Report: Training Data
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.53      0.38      0.44       682
#            1       0.55      0.69      0.61       753
#
#     accuracy                           0.54      1435
#    macro avg       0.54      0.54      0.53      1435
# weighted avg       0.54      0.54      0.53      1435
#
#
# Linear Discriminant Analysis Classification Report: Testing Data
# -------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.48      0.35      0.41       220
#            1       0.55      0.68      0.61       259
#
#     accuracy                           0.53       479
#    macro avg       0.52      0.52      0.51       479
# weighted avg       0.52      0.53      0.52       479

# %% [markdown]
# ### 6. Predicting the label with Neural Networks

# %%
# Simple hyperparamter selection to act as a starting point

MLP_accuracy={}
for i in range(1, 100, 5):
    MLP_model = MLPClassifier(hidden_layer_sizes=(i,i,i), activation='relu', solver='adam', max_iter=1500)
    MLP_model.fit(X_train_scaled, y_train)
    MLP_training_predictions = MLP_model.predict(X_train_scaled)
    y_pred_MLP = MLP_model.predict(X_test_scaled)
    Accuracy_MLP = metrics.accuracy_score(y_test, y_pred_MLP)
    MLP_accuracy[i]=Accuracy_MLP
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 12
#       9     Accuracy_MLP = metrics.accuracy_score(y_test, y_pred_MLP)
#      10     MLP_accuracy[i]=Accuracy_MLP
# ---> 12 optimal_layers = max(MLP_accuracy, key=lambda k: accuracy_dict[k])
#      14 print(f"Optimal no. of hidden layers is {optimal_layers} with an accuracy of {MLP_accuracy[optimal_layers]}")
#
# Cell In[79], line 12, in <lambda>(k)
#       9     Accuracy_MLP = metrics.accuracy_score(y_test, y_pred_MLP)
#      10     MLP_accuracy[i]=Accuracy_MLP
# ---> 12 optimal_layers = max(MLP_accuracy, key=lambda k: accuracy_dict[k])
#      14 print(f"Optimal no. of hidden layers is {optimal_layers} with an accuracy of {MLP_accuracy[optimal_layers]}")
#
# NameError: name 'accuracy_dict' is not defined

# %%
optimal_layers = max(MLP_accuracy, key=lambda k: MLP_accuracy[k])

print(f"Optimal no. of hidden layers is {optimal_layers}")
# Out:
# Optimal no. of hidden layers is 16

# %%
MLP_model = MLPClassifier(hidden_layer_sizes=(16,16,16), activation='relu', solver='adam', max_iter=1500)
MLP_model.fit(X_train_scaled, y_train)
MLP_training_predictions = MLP_model.predict(X_train_scaled)
y_pred_MLP = MLP_model.predict(X_test_scaled)
Accuracy_MLP = metrics.accuracy_score(y_test, y_pred_MLP)

print("MLP Accuracy:",Accuracy_MLP)
# Out:
# MLP Accuracy: 0.5177453027139874

# %%
# Generate the confusion matrix
cm_MLP = confusion_matrix(y_test, y_pred_MLP)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_MLP, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Multi-layer Perceptron Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

# Create and save the training classification report
training_report_MLP = classification_report(y_train, MLP_training_predictions)
testing_report_MLP = classification_report(y_test, y_pred_MLP)

# Print the training classification report
print("Multi-layer Perceptron Classification Report: Training Data")
print("-------------------------------------------------------------")
print(training_report_MLP)
print("")
print("Multi-layer Perceptron Classification Report: Testing Data")
print("--------------------------------------------------------------")
print(testing_report_MLP)
# Out:
# Multi-layer Perceptron Classification Report: Training Data
# -------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       682
#            1       0.93      0.94      0.93       753
#
#     accuracy                           0.93      1435
#    macro avg       0.93      0.93      0.93      1435
# weighted avg       0.93      0.93      0.93      1435
#
#
# Multi-layer Perceptron Classification Report: Testing Data
# --------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.47      0.46      0.47       220
#            1       0.55      0.56      0.56       259
#
#     accuracy                           0.52       479
#    macro avg       0.51      0.51      0.51       479
# weighted avg       0.52      0.52      0.52       479

# %% [markdown]
# ### 7. Predicting the label with K-Nearest Neighbors Algorithm (KNN)

# %%
# Simple hyperparamter selection to act as a starting point

KNN_accuracy={}
for i in range(1, 100, 5):
    KNN_model = KNeighborsClassifier(n_neighbors=i)

    # Train the model
    KNN_model.fit(X_train_scaled, y_train)
    KNN_training_predictions = KNN_model.predict(X_train_scaled)

    # Create predictions
    y_pred_KNN = model.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, y_pred)
    KNN_accuracy[i] = accuracy
    
optimal_n = max(KNN_accuracy, key=lambda k: KNN_accuracy[i])

print(f"Optimal no. of hidden layers is {optimal_n}")
# Out:
# Optimal no. of hidden layers is 1

# %%
KNN_model = KNeighborsClassifier(n_neighbors=1)

# Train the model
KNN_model.fit(X_train_scaled, y_train)
KNN_training_predictions = KNN_model.predict(X_train_scaled)

# Create predictions
y_pred_KNN = model.predict(X_test_scaled)
Accuracy_KNN = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.5532359081419624

# %%
# Generate the confusion matrix
cm_KNN = confusion_matrix(y_test, y_pred_KNN)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_KNN, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('K-Nearest Neighbors Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

# Create and save the training classification report
training_report_KNN = classification_report(y_train, KNN_training_predictions)
testing_report_KNN = classification_report(y_test, y_pred_KNN)

# Print the training classification report
print("K-Nearest Neighbors Classification Report: Training Data")
print("----------------------------------------------------------")
print(training_report_KNN)
print("")
print("K-Nearest Neighbors Classification Report: Testing Data")
print("----------------------------------------------------------")
print(testing_report_KNN)
# Out:
# K-Nearest Neighbors Classification Report: Training Data
# ----------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       682
#            1       1.00      1.00      1.00       753
#
#     accuracy                           1.00      1435
#    macro avg       1.00      1.00      1.00      1435
# weighted avg       1.00      1.00      1.00      1435
#
#
# K-Nearest Neighbors Classification Report: Testing Data
# ----------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.51      0.52      0.52       220
#            1       0.59      0.58      0.59       259
#
#     accuracy                           0.55       479
#    macro avg       0.55      0.55      0.55       479
# weighted avg       0.55      0.55      0.55       479

# %% [markdown]
# ### 8. Predicting the label with Decision Tree Algorithm

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
DT_training_predictions = model.predict (X_train_scaled)
y_pred_DT = model.predict(X_test_scaled)
Accuracy_DT = accuracy_score(y_test, y_pred_DT)

print(f"Accuracy: {Accuracy_DT}")
# Out:
# Accuracy: 0.5052192066805845

# %%
# Generate the confusion matrix
cm_DT = confusion_matrix(y_test, y_pred_DT)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_DT, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Decision Tree Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

# Create and save the training classification report
training_report_DT = classification_report(y_train, DT_training_predictions)
testing_report_DT = classification_report(y_test, y_pred_DT)

# Print the training classification report
print("Decision Tree Classification Report: Training Data")
print("---------------------------------------------------")
print(training_report_DT)
print("")
print("Decision Tree Classification Report: Testing Data")
print("---------------------------------------------------")
print(testing_report_DT)
# Out:
# Decision Tree Classification Report: Training Data
# ---------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.49      0.56      0.53       682
#            1       0.55      0.48      0.51       753
#
#     accuracy                           0.52      1435
#    macro avg       0.52      0.52      0.52      1435
# weighted avg       0.52      0.52      0.52      1435
#
#
# Decision Tree Classification Report: Testing Data
# ---------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.47      0.52      0.49       220
#            1       0.55      0.49      0.52       259
#
#     accuracy                           0.51       479
#    macro avg       0.51      0.51      0.50       479
# weighted avg       0.51      0.51      0.51       479

# %% [markdown]
# ### 9. Bagging Decision Tree

# %%
base_classifier = DecisionTreeClassifier(random_state=42)
bagging_classifier = BaggingClassifier(base_classifier, n_estimators=10, random_state=42)
bagging_classifier.fit(X_train_scaled, y_train)
BDT_training_predictions = bagging_classifier.predict(X_train_scaled)
y_pred_BDT = bagging_classifier.predict(X_test_scaled)
Accuracy_BDT = accuracy_score(y_test, y_pred_DT)

print(f"Accuracy: {Accuracy_BDT}")
# Out:
# Accuracy: 0.5052192066805845

# %%
# Generate the confusion matrix
cm_BDT = confusion_matrix(y_test, y_pred_BDT)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_BDT, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Bagging Decision Tree Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

# Create and save the training classification report
training_report_BDT = classification_report(y_train, BDT_training_predictions)
testing_report_BDT = classification_report(y_test, y_pred_BDT)

# Print the training classification report
print("Bagging Decision Tree Classification Report: Training Data")
print("---------------------------------------------------")
print(training_report_BDT)
print("")
print("Bagging Decision Tree Classification Report: Testing Data")
print("---------------------------------------------------")
print(testing_report_BDT)
# Out:
# Bagging Decision Tree Classification Report: Training Data
# ---------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       682
#            1       1.00      0.98      0.99       753
#
#     accuracy                           0.99      1435
#    macro avg       0.99      0.99      0.99      1435
# weighted avg       0.99      0.99      0.99      1435
#
#
# Bagging Decision Tree Classification Report: Testing Data
# ---------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.47      0.57      0.52       220
#            1       0.56      0.46      0.50       259
#
#     accuracy                           0.51       479
#    macro avg       0.51      0.51      0.51       479
# weighted avg       0.52      0.51      0.51       479

# %% [markdown]
# ### 10. Gradient Boosting Classifier

# %%
GBT_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
GBT_model.fit(X_train_scaled, y_train)
GBT_training_predictions = GBT_model.predict(X_train_scaled)
y_pred_GBT = GBT_model.predict(X_test_scaled)
Accuracy_GBT = accuracy_score(y_test, y_pred_GBT)
print(f"Accuracy: {Accuracy_GBT}")
# Out:
# Accuracy: 0.5156576200417536

# %%
# Generate the confusion matrix
cm_GBT = confusion_matrix(y_test, y_pred_GBT)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_GBT, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Gradient Boosting Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

# Create and save the training classification report
training_report_GBT = classification_report(y_train, DT_training_predictions)
testing_report_GBT = classification_report(y_test, y_pred_DT)

# Print the training classification report
print("Gradient Boosting Classification Report: Training Data")
print("-------------------------------------------------------")
print(training_report_GBT)
print("")
print("Gradient Boosting Classification Report: Testing Data")
print("-------------------------------------------------------")
print(testing_report_GBT)
# Out:
# Gradient Boosting Classification Report: Training Data
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.49      0.56      0.53       682
#            1       0.55      0.48      0.51       753
#
#     accuracy                           0.52      1435
#    macro avg       0.52      0.52      0.52      1435
# weighted avg       0.52      0.52      0.52      1435
#
#
# Gradient Boosting Classification Report: Testing Data
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.47      0.52      0.49       220
#            1       0.55      0.49      0.52       259
#
#     accuracy                           0.51       479
#    macro avg       0.51      0.51      0.50       479
# weighted avg       0.51      0.51      0.51       479

# %% [markdown]
# ### 11. Support Vector Machine (SVM)

# %%
svm_classifier = SVC(kernel='rbf',C=1.0, gamma='scale')
svm_classifier.fit(X_train_scaled, y_train)

SVM_training_predictions = svm_classifier.predict(X_train_scaled)

y_pred_SVM = svm_classifier.predict(X_test_scaled)

Accuracy_SVM = svm_classifier.score(X_test_scaled, y_test)

print(f"Accuracy: {Accuracy_SVM:.2f}")
# Out:
# Accuracy: 0.53

# %%
# Generate the confusion matrix
cm_SVM = confusion_matrix(y_test, y_pred_SVM)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_SVM, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Support Vector Machine Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

# Create and save the training classification report
training_report_SVM = classification_report(y_train, SVM_training_predictions)
testing_report_SVM = classification_report(y_test, y_pred_SVM)

# Print the training classification report
print("Support Vector Machine Classification Report: Training Data")
print("-------------------------------------------------------------")
print(training_report_SVM)
print("")
print("Support Vector Machine Classification Report: Testing Data")
print("-------------------------------------------------------------")
print(testing_report_SVM)
# Out:
# Support Vector Machine Classification Report: Training Data
# -------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.67      0.38      0.48       682
#            1       0.60      0.83      0.69       753
#
#     accuracy                           0.62      1435
#    macro avg       0.63      0.60      0.59      1435
# weighted avg       0.63      0.62      0.59      1435
#
#
# Support Vector Machine Classification Report: Testing Data
# -------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.48      0.28      0.35       220
#            1       0.55      0.75      0.63       259
#
#     accuracy                           0.53       479
#    macro avg       0.51      0.51      0.49       479
# weighted avg       0.52      0.53      0.50       479

# %% [markdown]
# ### 12. Naive Bayes Classifier

# %%
naive_bayes_classifier = GaussianNB()
naive_bayes_classifier.fit(X_train_scaled, y_train)
NB_training_predictions = naive_bayes_classifier.predict(X_train_scaled)
y_pred_NB = naive_bayes_classifier.predict(X_test_scaled)
Accuracy_NB = accuracy_score(y_test, y_pred_NB)

print(f"Accuracy: {Accuracy_NB}")
# Out:
# Accuracy: 0.46346555323590816

# %%
# Generate the confusion matrix
cm_NB = confusion_matrix(y_test, y_pred_NB)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(cm_NB, annot=True, ax=ax, fmt="d", linewidths=.5, linecolor='white', cmap="Reds")

# labels, title, and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Naive Bayes Confusion Matrix')
ax.xaxis.set_ticklabels(['Negative Class', 'Positive Class'])
ax.yaxis.set_ticklabels(['Negative Class', 'Positive Class'])

# Correct the bug from the heatmap function
b, t = plt.ylim()  # discover the values for bottom and top
b += 0.5  # Add 0.5 to the bottom
t -= 0.5  # Subtract 0.5 from the top
plt.ylim(b, t)  # update the ylim(bottom, top) values

plt.show()

# %%
# Print the classification report for the model

# Create and save the training classification report
training_report_NB = classification_report(y_train, NB_training_predictions)
testing_report_NB = classification_report(y_test, y_pred_NB)

# Print the training classification report
print("Naive Bayes Classification Report: Training Data")
print("---------------------------------------------------")
print(training_report_NB)
print("")
print("Naive Bayes Classification Report: Testing Data")
print("---------------------------------------------------")
print(testing_report_NB)
# Out:
# Naive Bayes Classification Report: Training Data
# ---------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.49      0.97      0.65       682
#            1       0.73      0.08      0.14       753
#
#     accuracy                           0.50      1435
#    macro avg       0.61      0.52      0.39      1435
# weighted avg       0.61      0.50      0.38      1435
#
#
# Naive Bayes Classification Report: Testing Data
# ---------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.46      0.95      0.62       220
#            1       0.54      0.05      0.09       259
#
#     accuracy                           0.46       479
#    macro avg       0.50      0.50      0.36       479
# weighted avg       0.50      0.46      0.33       479

# %% [markdown]
# ## Comparing our Accuracy Scores

# %%
accuracy_list = [Accuracy_RF, accuracy_XGB, Accuracy_TF2, 
                 Accuracy_LR, Accuracy_LDA, Accuracy_MLP,
                 Accuracy_DT, Accuracy_BDT, 
                 Accuracy_GBT, Accuracy_SVM, Accuracy_NB, Accuracy_KNN]

model_list = ['Random Forest', 'XGBoost', 'Tensor Flow','Logistic Regression', 
              'Linear Discriminat','Neural Network',
              'Decision Tree', 'Bagging Decision Tree', 'Gradient Boosting',
              'Support Vector Machine', 'Naive Bayes', 'KNN']
             

df_accuracy = pd.DataFrame({'Model': model_list, 'Accuracy': accuracy_list})

# %%
order = list(df_accuracy.sort_values('Accuracy', ascending=False).Model)
df_accuracy = df_accuracy.sort_values('Accuracy', ascending=False).reset_index().drop(['index'], axis=1)

# Set the grid color to white
sns.set_style("white", {'grid.color': 'white'})

plt.figure(figsize=(20, 8))

# Make a barplot and sort bars
x = sns.barplot(x='Model', y="Accuracy", data=df_accuracy, order=order, palette="rocket")

plt.xlabel("Model", fontsize=20)
plt.ylabel("Accuracy", fontsize=20)
plt.title("Accuracy by Model", fontsize=20)
plt.xticks(rotation=70, fontsize=12)
plt.ylim(0, 1)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1))

for i in range(len(model_list)):
    plt.text(x=i, y=df_accuracy.loc[i, 'Accuracy'] + 0.05, s=str(round((df_accuracy.loc[i, 'Accuracy']) * 100, 2)) + '%',
             fontsize=14, color='black', horizontalalignment='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hyper Parameter tuning XGBoost
#
# The XGboost model has achieved the highest accuracy among all the models. Now we will try to increase the performance even more. We will use a cross-validation approach and use GridSearchCV to find the best hyperparameters.

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score


# Create an XGBoost classifier
XGB_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss', use_label_encoder=False)

# Define the hyperparameter grid to search
param_grid = {
    'n_estimators': [100, 300,  700, 1000],  # Example values, adjust as needed
    'learning_rate': [0.01, 0.05, 0.1, 0.2],  # Example values, adjust as needed
    'max_depth': [3, 5, 7, 10]  # Example values, adjust as needed
}

# Use GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(XGB_model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train_scaled, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Train the model with the best hyperparameters
XGB_model_best = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss', use_label_encoder=False, **best_params)
XGB_model_best.fit(X_train_scaled, y_train)

# Make predictions
y_pred_XGB_best = XGB_model_best.predict(X_test_scaled)

# Evaluate the model
accuracy_XGB_best = accuracy_score(y_test, y_pred_XGB_best)
print(f"Best XGBoost Accuracy (Binary Classification): {accuracy_XGB_best} with hyperparameters: {best_params}")
# Out:
# Best XGBoost Accuracy (Binary Classification): 0.5615866388308977 with hyperparameters: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}

# %% [markdown]
# #### The hypertuned model yielded the same accuracy as our initial model.

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# In our task we will identify which features were the most valuable for our model. In our first step we will check if by any chance we can increase the accuracy of our model extracting a feature.

# %%
thresholds = sort(XGB_model.feature_importances_)
for thresh in thresholds:
    # select features using threshold
    selection = SelectFromModel(XGB_model, threshold=thresh, prefit=True)
    select_X_train = selection.transform(X_train_scaled)
    # train model
    selection_model = XGBClassifier()
    selection_model.fit(select_X_train, y_train)
    # eval model
    select_X_test = selection.transform(X_test_scaled)
    y_pred = selection_model.predict(select_X_test)
    predictions = [round(value) for value in y_pred]
    accuracy = accuracy_score(y_test, predictions)
    print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], accuracy*100.0))
# Out:
# Thresh=0.000, n=34, Accuracy: 56.16%
# Thresh=0.000, n=34, Accuracy: 56.16%
# Thresh=0.000, n=34, Accuracy: 56.16%
# Thresh=0.000, n=34, Accuracy: 56.16%
# Thresh=0.000, n=34, Accuracy: 56.16%
# Thresh=0.000, n=34, Accuracy: 56.16%
# Thresh=0.020, n=28, Accuracy: 56.16%
# Thresh=0.025, n=27, Accuracy: 53.44%
# Thresh=0.026, n=26, Accuracy: 53.86%
# Thresh=0.029, n=25, Accuracy: 52.40%
# Thresh=0.030, n=24, Accuracy: 52.61%
# Thresh=0.031, n=23, Accuracy: 54.07%
# Thresh=0.031, n=22, Accuracy: 50.52%
# Thresh=0.031, n=21, Accuracy: 48.43%
# Thresh=0.033, n=20, Accuracy: 51.77%
# Thresh=0.034, n=19, Accuracy: 48.85%
# Thresh=0.034, n=18, Accuracy: 53.86%
# Thresh=0.034, n=17, Accuracy: 53.44%
# Thresh=0.035, n=16, Accuracy: 50.52%
# Thresh=0.035, n=15, Accuracy: 53.86%
# Thresh=0.036, n=14, Accuracy: 50.94%
# Thresh=0.036, n=13, Accuracy: 50.52%
# Thresh=0.036, n=12, Accuracy: 50.52%
# Thresh=0.036, n=11, Accuracy: 54.91%
# Thresh=0.038, n=10, Accuracy: 49.90%
# Thresh=0.038, n=9, Accuracy: 49.48%
# Thresh=0.038, n=8, Accuracy: 49.27%
# Thresh=0.039, n=7, Accuracy: 50.73%
# Thresh=0.039, n=6, Accuracy: 48.64%
# Thresh=0.041, n=5, Accuracy: 54.70%
# Thresh=0.042, n=4, Accuracy: 54.70%
# Thresh=0.048, n=3, Accuracy: 54.70%
# Thresh=0.051, n=2, Accuracy: 54.07%
# Thresh=0.055, n=1, Accuracy: 54.07%

# %%
# replacing f1, f2 ... with feature names

feature_importance = XGB_model.get_booster().get_fscore()

real_feature_importance = {feature_names[int(key[1:])] : value for key, value in feature_importance.items()}

real_feature_importance
# Out:
# {'wr1': 115.0,
#  'wr2': 164.0,
#  'wr3': 170.0,
#  'wr4': 192.0,
#  'vol1': 107.0,
#  'vol2': 101.0,
#  'vol3': 76.0,
#  'vol4': 120.0,
#  'pe_ratio': 129.0,
#  'debt_to_equity': 149.0,
#  'quick_ratio': 147.0,
#  'total_shareholder_return': 133.0,
#  'profit_margin': 140.0,
#  'free_cash_margin': 168.0,
#  'volatility': 100.0,
#  'cpi': 99.0,
#  'interest_rate': 96.0,
#  'unemployment_rate': 61.0,
#  'sma': 124.0,
#  'rsi': 134.0,
#  'ema': 31.0,
#  'industry_Consumer Discretionary': 7.0,
#  'industry_Consumer Staples': 9.0,
#  'industry_Energy': 2.0,
#  'industry_Health Care': 6.0,
#  'industry_Industrials': 2.0,
#  'industry_Technology': 7.0,
#  'industry_Utilities': 4.0}

# %%
# Sort the dictionary by values in descending order
real_feature_importance = dict(sorted(real_feature_importance.items(), key=lambda item: item[1], reverse=True))

# Get the 'rocket' colormap
cmap = get_cmap('flare')
sns.set_style("white")

# Plot the horizontal bar chart
fig, ax = plt.subplots(figsize=(20, 8))

bars = ax.barh(list(real_feature_importance.keys())[::-1], list(real_feature_importance.values())[::-1], color=cmap(np.linspace(0, 1, len(real_feature_importance))))

# Set labels and title
ax.set_xlabel('F Score')
ax.set_ylabel('Features')
ax.set_title('XGBoost Feature Importance')

# Show the plot
plt.show()

# %% [markdown]
# ## Using PCA to reduce dimensionality

# %%
# Instantiate the PCA instance and declare the number of PCA variables
pca = PCA(n_components=3)


# Fit the PCA model on the transformed credit card DataFrame
X_pca = pca.fit_transform(X)

# Review the first 5 rows of list data
X_pca[:5]

# Calculate the PCA explained variance ratio
print("Explained variance: ", pca.explained_variance_ratio_)
print("Sum of explained variance: ", sum(pca.explained_variance_ratio_))

# Create the PCA DataFrame
X_pca_df = pd.DataFrame(
    X_pca,
    columns=["PCA1", "PCA2", "PCA3"]
)
# Out:
# Explained variance:  [0.91025545 0.05117109 0.02927404]
# Sum of explained variance:  0.990700583075814

# %%
X_pca_df
# Out:
#               PCA1          PCA2          PCA3
# 0     2.784571e+06 -2.581661e+05 -1.701684e+05
# 1    -1.008317e+07  1.459226e+05  4.838458e+05
# 2    -7.353321e+06  1.370539e+06  1.468765e+06
# 3    -8.485450e+06  1.392496e+05  3.477754e+05
# 4     5.869763e+06 -3.174888e+06 -1.125774e+06
# ...            ...           ...           ...
# 1909 -8.089713e+06  1.342631e+05  1.211967e+05
# 1910 -8.579890e+06  4.058011e+05  5.712314e+05
# 1911 -9.082717e+06  5.754009e+05  5.161767e+05
# 1912  5.571034e+06 -8.002231e+06 -1.762576e+06
# 1913 -8.190653e+06  5.071915e+05  5.043818e+05
#
# [1914 rows x 3 columns]

# %%
# Splitting into Train and Test sets
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca_df, y, random_state=78)

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler_pca = scaler.fit(X_train_pca)

# Scaling data
X_train_scaled_pca = X_scaler_pca.transform(X_train_pca)
X_test_scaled_pca = X_scaler_pca.transform(X_test_pca)

# %%
# Create a binary XGBoost model
XGB_model_pca = xgb.XGBClassifier(objective='binary:logistic')

# Train the model
XGB_model_pca.fit(X_train_scaled_pca, y_train)

# Make predictions on the test set
y_pred_XGB_pca = XGB_model_pca.predict(X_test_scaled_pca)

# Calculate accuracy
accuracy_XGB_pca = metrics.accuracy_score(y_test, y_pred_XGB_pca)
print("XGB Accuracy (Binary Classification) using PCA:", accuracy_XGB_pca)
# Out:
# XGB Accuracy (Binary Classification) using PCA: 0.4906054279749478

# %% [markdown]
# ## Using the feature importance chart to reduce dimensionality

# %%
# starting with 5 most important columns
top_5_columns = list(real_feature_importance.keys())[:5]
# Out:
# ['wr4', 'wr3', 'free_cash_margin', 'wr2', 'debt_to_equity']

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
y = df["label"]

# Separate the X variable, the features
X = df[top_5_columns]

# %%
# reviewing feature set
X.head()
# Out:
#         wr4       wr3  free_cash_margin       wr2  debt_to_equity
# 0 -0.007692 -0.009555             13.74  0.042774            0.63
# 1  0.031470 -0.006826              1.49  0.011924            0.85
# 2  0.036994 -0.040843             29.98 -0.004482            0.60
# 3 -0.058078  0.055392            -18.14  0.062964            0.36
# 4 -0.028000  0.021842             10.21 -0.021995            1.35

# %%
# Splitting into Train and Test sets
X_train_5, X_test_5, y_train, y_test = train_test_split(X, y, random_state=78)

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler_5 = scaler.fit(X_train_5)

# Scaling data
X_train_scaled_5 = X_scaler_5.transform(X_train_5)
X_test_scaled_5 = X_scaler_5.transform(X_test_5)

# %%
# Create a binary XGBoost model
XGB_model_5 = xgb.XGBClassifier(objective='binary:logistic')

# Train the model
XGB_model_5.fit(X_train_scaled_5, y_train)

# Make predictions on the test set
y_pred_XGB_5 = XGB_model_5.predict(X_test_scaled_5)

# Calculate accuracy
accuracy_XGB_5 = metrics.accuracy_score(y_test, y_pred_XGB_5)
print("XGB Accuracy (Binary Classification) using top 5 features:", accuracy_XGB_5)
# Out:
# XGB Accuracy (Binary Classification) using top 5 features: 0.5010438413361169

# %%
# using 10 most important columns
top_10_columns = list(real_feature_importance.keys())[:10]

# Separate the data into labels and features
# Separate the y variable, the labels
y = df["label"]

# Separate the X variable, the features
X = df[top_10_columns]


# Splitting into Train and Test sets
X_train_10, X_test_10, y_train, y_test = train_test_split(X, y, random_state=78)

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler_10 = scaler.fit(X_train_10)

# Scaling data
X_train_scaled_10 = X_scaler_10.transform(X_train_10)
X_test_scaled_10 = X_scaler_10.transform(X_test_10)

# %%
# Create a binary XGBoost model
XGB_model_10 = xgb.XGBClassifier(objective='binary:logistic')

# Train the model
XGB_model_10.fit(X_train_scaled_10, y_train)

# Make predictions on the test set
y_pred_XGB_10 = XGB_model_10.predict(X_test_scaled_10)

# Calculate accuracy
accuracy_XGB_10 = metrics.accuracy_score(y_test, y_pred_XGB_10)
print("XGB Accuracy (Binary Classification) using top 10 features:", accuracy_XGB_10)
# Out:
# XGB Accuracy (Binary Classification) using top 10 features: 0.5615866388308977

# %%
# Using 15 most important columns
top_15_columns = list(real_feature_importance.keys())[:15]

# Separate the data into labels and features
# Separate the y variable, the labels
y = df["label"]

# Separate the X variable, the features
X = df[top_15_columns]

# Splitting into Train and Test sets
X_train_15, X_test_15, y_train, y_test = train_test_split(X, y, random_state=78)

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaler
X_scaler_15 = scaler.fit(X_train_15)

# Scaling data
X_train_scaled_15 = X_scaler_15.transform(X_train_15)
X_test_scaled_15 = X_scaler_15.transform(X_test_15)

# Create a binary XGBoost model
XGB_model_15 = xgb.XGBClassifier(objective='binary:logistic')

# Train the model
XGB_model_15.fit(X_train_scaled_15, y_train)

# Make predictions on the test set
y_pred_XGB_15 = XGB_model_15.predict(X_test_scaled_15)

# Calculate accuracy
accuracy_XGB_15 = metrics.accuracy_score(y_test, y_pred_XGB_15)
print("XGB Accuracy (Binary Classification) using top 15 features:", accuracy_XGB_15)
# Out:
# XGB Accuracy (Binary Classification) using top 15 features: 0.5365344467640919

# %% [markdown]
# ## Removing outliers

# %%
# Select numeric columns for outlier removal
numeric_columns = df.select_dtypes(include=['float64']).columns

# Calculate Z-scores for each numeric column
z_scores = zscore(df[numeric_columns])

# Define a threshold for outlier detection (e.g., Z-score greater than 3 or less than -3)
threshold = 3

# Create a boolean mask for outliers
outliers_mask = (np.abs(z_scores) > threshold).any(axis=1)

# Create a new DataFrame without outliers
df_no_outliers = df[~outliers_mask]

# Display the shape of the original and new DataFrames
print("Original DataFrame shape:", df.shape)
print("DataFrame without outliers shape:", df_no_outliers.shape)
# Out:
# Original DataFrame shape: (1914, 23)
# DataFrame without outliers shape: (1654, 23)

# %%
# using all columns
# One-hot encode the 'industry' column

# Separate the y variable, the labels
y = df_no_outliers["label"]

# Separate the X variable, the features
X = df_no_outliers.drop(columns = "label")

X = pd.get_dummies(X, columns=['industry'])

X.shape
# Out:
# (1654, 34)

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Creating StandardScaler instance
scaler = StandardScaler()

# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Create a binary XGBoost model
XGB_model_no = xgb.XGBClassifier(objective='binary:logistic')

# Train the model
XGB_model_no.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred_XGB_no = XGB_model_no.predict(X_test_scaled)

# Calculate accuracy
accuracy_XGB_no = metrics.accuracy_score(y_test, y_pred_XGB_no)
print("XGB Accuracy (Binary Classification) using No Outliers:", accuracy_XGB_no)
# Out:
# XGB Accuracy (Binary Classification) using No Outliers: 0.5483091787439613

# %% [markdown]
# ## Charting our hypertuning efforts

# %%
# compiling models and accuracies

accuracy_list = [accuracy_XGB, accuracy_XGB_best, accuracy_XGB_pca ,accuracy_XGB_5, accuracy_XGB_10 ,accuracy_XGB_15, accuracy_XGB_no]

model_list = ['Original', 'Cross Validation Approach', 'PCA', 'Top 5 Features', 'Top 10 Features', 'Top 15 Features', 'Removing Outliers' ]
             
df_accuracy = pd.DataFrame({'Model': model_list, 'Accuracy': accuracy_list})

# %%
order = list(df_accuracy.sort_values('Accuracy', ascending=False).Model)
df_accuracy = df_accuracy.sort_values('Accuracy', ascending=False).reset_index().drop(['index'], axis=1)

# Set the grid color to white
sns.set_style("white", {'grid.color': 'white'})

plt.figure(figsize=(20, 8))

# Make a barplot and sort bars
x = sns.barplot(x='Model', y="Accuracy", data=df_accuracy, order=order, palette="rocket")

plt.xlabel("Model", fontsize=20)
plt.ylabel("Accuracy", fontsize=20)
plt.title("Accuracy by Model", fontsize=20)
plt.xticks(rotation=0, fontsize=12)
plt.ylim(0, 1)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1))

for i in range(len(model_list)):
    plt.text(x=i, y=df_accuracy.loc[i, 'Accuracy'] + 0.05, s=str(round((df_accuracy.loc[i, 'Accuracy']) * 100, 2)) + '%',
             fontsize=14, color='black', horizontalalignment='center')

plt.tight_layout()
plt.show()
